# %%
import pandas as pd
from matplotlib import pyplot as pl
import math
import numpy as np
from collections import Counter
from pandas import ExcelWriter

# %%
data1 = pd.read_csv('Fuel cell (malaysia).csv')

# %%
data1
# Out:
#     Publication Type                                            Authors  \
# 0                  J  Abdullah, N; Saidur, R; Zainoodin, AM; Aslfatt...
# 1                  J  Al-Ogaili, AS; Ramasamy, A; Hashim, TJT; Al-Ma...
# 2                  J  Misha, S; Abdullah, AL; Tamaldin, N; Rosli, MA...
# 3                  J  Jalil, MH; Nasir, SNFM; Ismail, MI; Othman, MY...
# 4                  J  Basri, S; Hazri, NS; Selladurai, SR; Zainoodin...
# ..               ...                                                ...
# 809                J                     Nasef, MM; Saidi, H; Yarmo, MA
# 810                J            Nasef, MM; Saidi, H; Nor, HM; Yarmo, MA
# 811                J              Nasef, MM; Saidi, H; Nor, HM; Foo, OM
# 812                J         Lwin, Y; Daud, WRW; Mohamad, AB; Yaakob, Z
# 813                J                                          Nasef, MM
#
#      Book Authors  Book Editors  Book Group Authors  \
# ...

# %%
def keywords_more(x):
    a = x['Author Keywords'].str.lower()
    b = x['Publication Year']
    c = x['Article Title'].str.lower()
    d = x['Keywords Plus'].str.lower()
    e = x['Abstract'].str.lower()
    
    df = pd.DataFrame()
    df = df.assign(Year=b, Article_Title=c, Author_Keywords=a, Keywords_Plus=d, Abstract=e)
    df = df.reset_index(drop=True)
    print(len(df))
    
    df1 = df[~df['Article_Title'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b|'
                                              'microbial|biofuel cell|\bmfc\b|'
                                              'solid oxide|sofc|'
                                              'direct methanol|dmfc|'
                                              'alkaline|\bafc\b|'
                                              'phosphoric acid|pafc|'
                                              'molten carbonate|mcfc|'
                                              'photocatalytic|\bpfc\b|'
                                              'direct glycerol fuel cell|\bdgfc\b|'
                                              'direct formic acid fuel cell|\bdfafc\b|'
                                              'direct ethanol|\bdefc\b')]

    df1 = df1.reset_index(drop=True)
    df1 = df1.dropna()
    #print(df1,'\n')
    print(len(df1))
    #print(df1.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df2 = df1[~df1['Author_Keywords'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b|'
                                              'microbial|biofuel cell|\bmfc\b|'
                                              'solid oxide|sofc|'
                                              'direct methanol|dmfc|'
                                              'alkaline|\bafc\b|'
                                              'phosphoric acid|pafc|'
                                              'molten carbonate|mcfc|'
                                              'photocatalytic|\bpfc\b|'
                                              'direct glycerol fuel cell|\bdgfc\b|'
                                              'direct formic acid fuel cell|\bdfafc\b|'
                                              'direct ethanol|\bdefc\b')]
    df2 = df2.reset_index(drop=True)
    #print(df2)
    print(len(df2))
    
    df3 = df2[~df2['Keywords_Plus'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b|'
                                              'microbial|biofuel cell|\bmfc\b|'
                                              'solid oxide|sofc|'
                                              'direct methanol|dmfc|'
                                              'alkaline|\bafc\b|'
                                              'phosphoric acid|pafc|'
                                              'molten carbonate|mcfc|'
                                              'photocatalytic|\bpfc\b|'
                                              'direct glycerol fuel cell|\bdgfc\b|'
                                              'direct formic acid fuel cell|\bdfafc\b|'
                                              'direct ethanol|\bdefc\b')]
    df3 = df3.reset_index(drop=True)
    #print(df3)
    print(len(df3))
    
    df4 = df3[~df3['Abstract'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b|'
                                              'microbial|biofuel cell|\bmfc\b|'
                                              'solid oxide|sofc|'
                                              'direct methanol|dmfc|'
                                              'alkaline|\bafc\b|'
                                              'phosphoric acid|pafc|'
                                              'molten carbonate|mcfc|'
                                              'photocatalytic|\bpfc\b|'
                                              'direct glycerol fuel cell|\bdgfc\b|'
                                              'direct formic acid fuel cell|\bdfafc\b|'
                                              'direct ethanol|\bdefc\b')]
    df4 = df4.reset_index(drop=True)
    print(len(df4))
    #print(df4[150:200])
    
    df5 = df4[~df4['Abstract'].str.contains(r'oxygen reduction reaction|sintering|electrical conductivity|'
                                            'optimization|electricity generation')&\
              ~df4['Author_Keywords'].str.contains(r'oxygen reduction reaction|sintering|electrical conductivity|'
                                            'optimization|electricity generation')&\
              ~df4['Keywords_Plus'].str.contains(r'oxygen reduction reaction|sintering|electrical conductivity|'
                                            'optimization|electricity generation')&\
              ~df4['Abstract'].str.contains(r'oxygen reduction reaction|sintering|electrical conductivity|'
                                            'optimization|electricity generation')]
    df5 = df5.reset_index(drop=True)
    #print(len(df5))
    
    df6 = df5[df5['Abstract'].str.contains(r'wastewater treatment')|\
              df5['Author_Keywords'].str.contains(r'wastewater treatment')|\
              df5['Keywords_Plus'].str.contains(r'wastewater treatment')|\
              df5['Abstract'].str.contains(r'wastewater treatment')]
    df6 = df6.reset_index(drop=True)
    #print(len(df6))
    
    df7 = df4[df4['Abstract'].str.contains(r'algae')|\
              df4['Author_Keywords'].str.contains(r'algae')|\
              df4['Keywords_Plus'].str.contains(r'algae')|\
              df4['Abstract'].str.contains(r'algae')]
    df7 = df7.reset_index(drop=True)
    #print(len(df7))
    
    
    #pd.options.display.max_colwidth = 200
    
keywords_more(data1)
# Out:
# 814
# 326
# 271
# 221
# 180

# %%
def keywords_m(x):
    a = x['Author Keywords'].str.lower()
    b = x['Publication Year']
    c = x['Article Title'].str.lower()
    d = x['Keywords Plus'].str.lower()
    e = x['Abstract'].str.lower()
    
    df = pd.DataFrame()
    df = df.assign(Year=b, Article_Title=c, Author_Keywords=a, Keywords_Plus=d, Abstract=e)
    df = df.dropna()
    
    df1 = df[df['Article_Title'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b')|\
             df['Author_Keywords'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b')|\
             df['Keywords_Plus'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b')|\
             
                                              
    #print(df1,'\n')
    print(len(df1))
    
    df2 = df1[~df1['Article_Title'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc')]
    df2 = df2.reset_index(drop=True)
    #print(df2)
    print(len(df2))
    df3 = df2[~df2['Author_Keywords'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc')]
    df3 = df3.reset_index(drop=True)
    #print(df3)
    print(len(df3))
    df4 = df3[~df3['Keywords_Plus'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc')]
    df4 = df4.reset_index(drop=True)
    #print(df4)
    print(len(df4))
    df5 = df4[~df4['Abstract'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc')]
    df5 = df5.reset_index(drop=True)
    #print(df5)
    print(len(df5))
    
    
    
keywords_m(data1)
# Out:
# 183
# 111
# 74
# 47
# 9

# %%
def keywords_stack(x):
    a = x['Author Keywords'].str.lower()
    b = x['Publication Year']
    c = x['Article Title'].str.lower()
    d = x['Keywords Plus'].str.lower()
    e = x['Abstract'].str.lower()
    
    df = pd.DataFrame()
    df = df.assign(Year=b, Article_Title=c, Author_Keywords=a, Keywords_Plus=d, Abstract=e)
    #df = df.dropna()
    df = df.reset_index(drop=True)
    print(len(df))
    
    df1 = df[df['Article_Title'].str.contains(r'microbial|biofuel cell|\bmfc\b')|\
             df['Author_Keywords'].str.contains(r'microbial|biofuel cell|\bmfc\b')|\
             df['Keywords_Plus'].str.contains(r'microbial|biofuel cell|\bmfc\b')|\
             df['Abstract'].str.contains(r'microbial|biofuel cell|\bmfc\b')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    print(len(df1))
    
    
    df2 = df1[df1['Article_Title'].str.contains(r'electrode|anode|cathode')|\
             df1['Author_Keywords'].str.contains(r'electrode|anode|cathode')|\
             df1['Keywords_Plus'].str.contains(r'electrode|anode|cathode')|\
             df1['Abstract'].str.contains(r'electrode|anode|cathode')]
    df2 = df2.reset_index(drop=True)
    #print(df2,'\n')
    print('electrode|anode|cathode:',len(df2))
    
    #print(df2.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df3 = df1[df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte')]
    df3 = df3.reset_index(drop=True)
    #print(df3,'\n')
    print('electrolyte:',len(df3))
    
    #print(df3.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df4 = df1[df1['Article_Title'].str.contains(r'catalyst')|\
              df1['Author_Keywords'].str.contains(r'catalyst')|\
              df1['Keywords_Plus'].str.contains(r'catalyst')|\
              df1['Abstract'].str.contains(r'catalyst')]
    df4 = df4.reset_index(drop=True)
    #print(df4,'\n')
    print('catalyst:',len(df4))
    
    #print(df4.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df5 = df1[df1['Article_Title'].str.contains(r'electrolyte') & df1['Article_Title'].str.contains(r'catalyst') & df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte') & df1['Author_Keywords'].str.contains(r'catalyst') & df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte') & df1['Keywords_Plus'].str.contains(r'catalyst') & df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte') & df1['Abstract'].str.contains(r'catalyst') & df1['Abstract'].str.contains(r'electrolyte')]
    df5 = df5.reset_index(drop=True)
    #print(df5,'\n')
    #print(len(df5))
    
    #print(df5.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df6 = df1[df1['Article_Title'].str.contains('station|power generation')|\
              df1['Author_Keywords'].str.contains('station|power generation')|\
              df1['Keywords_Plus'].str.contains('station|power generation')|\
              df1['Abstract'].str.contains('station|power generation')]
    df6 = df6.reset_index(drop=True)
    #print(df6,'\n')
    print('station|power generation:',len(df6))
    
    print(df6.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    
    df7 = df1[df1['Article_Title'].str.contains('biosensor')|\
              df1['Author_Keywords'].str.contains('biosensor')|\
              df1['Keywords_Plus'].str.contains('biosensor')|\
              df1['Abstract'].str.contains('biosensor')]
    df7 = df7.reset_index(drop=True)
    #print(df7,'\n')
    print('biosensor:',len(df7))
    
    #pd.options.display.max_colwidth = 500
    
    print(df7.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df8 = df1[df1['Article_Title'].str.contains('wastewater treatment')|\
              df1['Author_Keywords'].str.contains('wastewater treatment')|\
              df1['Keywords_Plus'].str.contains('wastewater treatment')|\
              df1['Abstract'].str.contains('wastewater treatment')]
    df8 = df8.reset_index(drop=True)
    #print(df8,'\n')
    print('wastewater treatment:',len(df8))
    
    print(df8.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df9 = df1[df1['Article_Title'].str.contains('application')|\
              df1['Author_Keywords'].str.contains('application')|\
              df1['Keywords_Plus'].str.contains('application')|\
              df1['Abstract'].str.contains('application')]
    df9 = df9.reset_index(drop=True)
    #print(df9,'\n')
    #print(len(df9))
    
    #print(df9.groupby(['Year']).size().reset_index(name='counts'),'\n')

keywords_stack(data1)
# Out:
# 814
# 171
# electrode|anode|cathode: 121
# electrolyte: 10
# catalyst: 41
# station|power generation: 48
#    Year  counts
# 0  2011       2
# 1  2012       1
# 2  2013       4
# 3  2014       1
# 4  2015       4
# 5  2016       5
# 6  2017      11
# 7  2018       7
# 8  2019       9
# 9  2020       4
#
# biosensor: 5
#    Year  counts
# 0  2014       1
# 1  2015       2
# 2  2016       1
# 3  2019       1
#
# wastewater treatment: 41
#    Year  counts
# 0  2011       2
# 1  2012       1
# 2  2013       3
# 3  2015       6
# 4  2016       2
# 5  2017       9
# 6  2018       9
# 7  2019       4
# 8  2020       5

# %%
def keywords_stack2(x):
    a = x['Author Keywords'].str.lower()
    b = x['Publication Year']
    c = x['Article Title'].str.lower()
    d = x['Keywords Plus'].str.lower()
    e = x['Abstract'].str.lower()
    
    df = pd.DataFrame()
    df = df.assign(Year=b, Article_Title=c, Author_Keywords=a, Keywords_Plus=d, Abstract=e)
    df = df.reset_index(drop=True)
    print(len(df))
    
    df1 = df[df['Article_Title'].str.contains(r'solid oxide|sofc')|\
             df['Author_Keywords'].str.contains(r'solid oxide|sofc')|\
             df['Keywords_Plus'].str.contains(r'solid oxide|sofc')|\
             df['Abstract'].str.contains(r'solid oxide|sofc')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    print(len(df1))
    
    
    df2 = df1[df1['Article_Title'].str.contains(r'electrode|anode|cathode')|\
             df1['Author_Keywords'].str.contains(r'electrode|anode|cathode')|\
             df1['Keywords_Plus'].str.contains(r'electrode|anode|cathode')|\
             df1['Abstract'].str.contains(r'electrode|anode|cathode')]
    df2 = df2.reset_index(drop=True)
    #print(df2,'\n')
    print('electrode|anode|cathode:',len(df2))
    
    print(df2.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df3 = df1[df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte')]
    df3 = df3.reset_index(drop=True)
    #print(df3,'\n')
    print('electrolyte:',len(df3))
    
    print(df3.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df4 = df1[df1['Article_Title'].str.contains(r'catalyst')|\
              df1['Author_Keywords'].str.contains(r'catalyst')|\
              df1['Keywords_Plus'].str.contains(r'catalyst')|\
              df1['Abstract'].str.contains(r'catalyst')]
    df4 = df4.reset_index(drop=True)
    #print(df4,'\n')
    print('catalyst:',len(df4))
    
    print(df4.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df5 = df1[df1['Article_Title'].str.contains(r'electrolyte') & df1['Article_Title'].str.contains(r'catalyst') & df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte') & df1['Author_Keywords'].str.contains(r'catalyst') & df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte') & df1['Keywords_Plus'].str.contains(r'catalyst') & df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte') & df1['Abstract'].str.contains(r'catalyst') & df1['Abstract'].str.contains(r'electrolyte')]
    df5 = df5.reset_index(drop=True)
    #print(df5,'\n')
    #print(len(df5))
    
    #print(df5.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df6 = df1[df1['Article_Title'].str.contains('transport')|\
              df1['Author_Keywords'].str.contains('transport')|\
              df1['Keywords_Plus'].str.contains('transport')|\
              df1['Abstract'].str.contains('transport')]
    df6 = df6.reset_index(drop=True)
    #print(df6,'\n')
    print('transport:',len(df6))
    
    print(df6.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    
    df7 = df1[df1['Article_Title'].str.contains('station|power generation')|\
              df1['Author_Keywords'].str.contains('station|power generation')|\
              df1['Keywords_Plus'].str.contains('station|power generation')|\
              df1['Abstract'].str.contains('station|power generation')]
    df7 = df7.reset_index(drop=True)
    #print(df7,'\n')
    print('station|power generation:',len(df7))
    
    #pd.options.display.max_colwidth = 500
    
    print(df7.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df8 = df1[df1['Article_Title'].str.contains('portable')|\
              df1['Author_Keywords'].str.contains('portable')|\
              df1['Keywords_Plus'].str.contains('portable')|\
              df1['Abstract'].str.contains('portable')]
    df8 = df8.reset_index(drop=True)
    #print(df8,'\n')
    print('portable:',len(df8))
    
    print(df8.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df9 = df1[df1['Article_Title'].str.contains('application')|\
              df1['Author_Keywords'].str.contains('application')|\
              df1['Keywords_Plus'].str.contains('application')|\
              df1['Abstract'].str.contains('application')]
    df9 = df9.reset_index(drop=True)
    #print(df9,'\n')
    #print(len(df9))
    
    #print(df9.groupby(['Year']).size().reset_index(name='counts'),'\n')

keywords_stack2(data1)
# Out:
# 814
# 129
# electrode|anode|cathode: 95
#     Year  counts
# 0   2009       1
# 1   2011       1
# 2   2012       6
# 3   2013       6
# 4   2014       6
# 5   2015       4
# 6   2016      10
# 7   2017      16
# 8   2018      16
# 9   2019      13
# 10  2020      16
#
# electrolyte: 64
#    Year  counts
# 0  2012       5
# 1  2013       4
# 2  2014       5
# 3  2015       3
# 4  2016       9
# 5  2017      14
# 6  2018       7
# 7  2019      10
# 8  2020       7
#
# catalyst: 6
#    Year  counts
# 0  2017       1
# 1  2019       2
# 2  2020       3
#
# transport: 13
#    Year  counts
# 0  2012       2
# 1  2013       2
# 2  2015       1
# 3  2016       1
# 4  2017       3
# 5  2019       3
# 6  2020       1
#
# station|power generation: 9
#    Year  counts
# 0  2015       1
# 1  2016       1
# 2  2017       1
# 3  2018       1
# 4  2019       4
# 5  2020       1
#
# portable: 1
#    Year  counts
# 0  2019       1

# %%
def keywords_stack3(x):
    a = x['Author Keywords'].str.lower()
    b = x['Publication Year']
    c = x['Article Title'].str.lower()
    d = x['Keywords Plus'].str.lower()
    e = x['Abstract'].str.lower()
    
    df = pd.DataFrame()
    df = df.assign(Year=b, Article_Title=c, Author_Keywords=a, Keywords_Plus=d, Abstract=e)
    df = df.reset_index(drop=True)
    print(len(df))
    
    df1 = df[df['Article_Title'].str.contains(r'direct methanol|dmfc')|\
             df['Author_Keywords'].str.contains(r'direct methanol|dmfc')|\
             df['Keywords_Plus'].str.contains(r'direct methanol|dmfc')|\
             df['Abstract'].str.contains(r'direct methanol|dmfc')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    print(len(df1))
    
    
    df2 = df1[df1['Article_Title'].str.contains(r'electrode|anode|cathode')|\
             df1['Author_Keywords'].str.contains(r'electrode|anode|cathode')|\
             df1['Keywords_Plus'].str.contains(r'electrode|anode|cathode')|\
             df1['Abstract'].str.contains(r'electrode|anode|cathode')]
    df2 = df2.reset_index(drop=True)
    #print(df2,'\n')
    print('electrode|anode|cathode:',len(df2))
    
    print(df2.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df3 = df1[df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte')]
    df3 = df3.reset_index(drop=True)
    #print(df3,'\n')
    print('electrolyte:',len(df3))
    
    print(df3.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df4 = df1[df1['Article_Title'].str.contains(r'catalyst')|\
              df1['Author_Keywords'].str.contains(r'catalyst')|\
              df1['Keywords_Plus'].str.contains(r'catalyst')|\
              df1['Abstract'].str.contains(r'catalyst')]
    df4 = df4.reset_index(drop=True)
    #print(df4,'\n')
    print('catalyst:',len(df4))
    
    print(df4.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df5 = df1[df1['Article_Title'].str.contains(r'electrolyte') & df1['Article_Title'].str.contains(r'catalyst') & df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte') & df1['Author_Keywords'].str.contains(r'catalyst') & df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte') & df1['Keywords_Plus'].str.contains(r'catalyst') & df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte') & df1['Abstract'].str.contains(r'catalyst') & df1['Abstract'].str.contains(r'electrolyte')]
    df5 = df5.reset_index(drop=True)
    #print(df5,'\n')
    #print(len(df5))
    
    #print(df5.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df6 = df1[df1['Article_Title'].str.contains('transport')|\
              df1['Author_Keywords'].str.contains('transport')|\
              df1['Keywords_Plus'].str.contains('transport')|\
              df1['Abstract'].str.contains('transport')]
    df6 = df6.reset_index(drop=True)
    #print(df6,'\n')
    print('transport:',len(df6))
    
    print(df6.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    
    df7 = df1[df1['Article_Title'].str.contains('station|power generation')|\
              df1['Author_Keywords'].str.contains('station|power generation')|\
              df1['Keywords_Plus'].str.contains('station|power generation')|\
              df1['Abstract'].str.contains('station|power generation')]
    df7 = df7.reset_index(drop=True)
    #print(df7,'\n')
    print('station|power generation:',len(df7))
    
    #pd.options.display.max_colwidth = 500
    
    print(df7.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df8 = df1[df1['Article_Title'].str.contains('portable')|\
              df1['Author_Keywords'].str.contains('portable')|\
              df1['Keywords_Plus'].str.contains('portable')|\
              df1['Abstract'].str.contains('portable')]
    df8 = df8.reset_index(drop=True)
    #print(df8,'\n')
    print('portable:',len(df8))
    
    print(df8.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df9 = df1[df1['Article_Title'].str.contains('application')|\
              df1['Author_Keywords'].str.contains('application')|\
              df1['Keywords_Plus'].str.contains('application')|\
              df1['Abstract'].str.contains('application')]
    df9 = df9.reset_index(drop=True)
    #print(df9,'\n')
    #print(len(df9))
    
    #print(df9.groupby(['Year']).size().reset_index(name='counts'),'\n')

    
    

keywords_stack3(data1)
# Out:
# 814
# 89
# electrode|anode|cathode: 37
#     Year  counts
# 0   2009       2
# 1   2010       4
# 2   2011       1
# 3   2013       2
# 4   2014       6
# 5   2015       4
# 6   2016       3
# 7   2017       5
# 8   2018       1
# 9   2019       7
# 10  2020       2
#
# electrolyte: 34
#     Year  counts
# 0   2006       1
# 1   2007       1
# 2   2008       1
# 3   2009       3
# 4   2011       1
# 5   2012       1
# 6   2013       3
# 7   2014       1
# 8   2015       1
# 9   2016       1
# 10  2017       3
# 11  2018       5
# 12  2019       5
# 13  2020       7
#
# catalyst: 40
#    Year  counts
# 0  2009       2
# 1  2010       4
# 2  2013       1
# 3  2014       4
# 4  2015       4
# 5  2016       3
# 6  2017       6
# 7  2018       1
# 8  2019      10
# 9  2020       5
#
# transport: 17
#    Year  counts
# 0  2006       1
# 1  2009       3
# 2  2010       1
# 3  2011       1
# 4  2013       2
# 5  2014       2
# 6  2015       2
# 7  2017       1
# 8  2018       1
# ...

# %%
def keywords_stack4(x):
    a = x['Author Keywords'].str.lower()
    b = x['Publication Year']
    c = x['Article Title'].str.lower()
    d = x['Keywords Plus'].str.lower()
    e = x['Abstract'].str.lower()
    
    df = pd.DataFrame()
    df = df.assign(Year=b, Article_Title=c, Author_Keywords=a, Keywords_Plus=d, Abstract=e)
    df = df.reset_index(drop=True)
    print(len(df))
    
    df1 = df[df['Article_Title'].str.contains(r'alkaline|\bafc\b')|\
             df['Author_Keywords'].str.contains(r'alkaline|\bafc\b')|\
             df['Keywords_Plus'].str.contains(r'alkaline|\bafc\b')|\
             df['Abstract'].str.contains(r'alkaline|\bafc\b')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    print(len(df1))
    
    
    df2 = df1[df1['Article_Title'].str.contains(r'electrode|anode|cathode')|\
             df1['Author_Keywords'].str.contains(r'electrode|anode|cathode')|\
             df1['Keywords_Plus'].str.contains(r'electrode|anode|cathode')|\
             df1['Abstract'].str.contains(r'electrode|anode|cathode')]
    df2 = df2.reset_index(drop=True)
    #print(df2,'\n')
    print('electrode|anode|cathode:',len(df2))
    
    print(df2.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df3 = df1[df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte')]
    df3 = df3.reset_index(drop=True)
    #print(df3,'\n')
    print('electrolyte:',len(df3))
    
    print(df3.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df4 = df1[df1['Article_Title'].str.contains(r'catalyst')|\
              df1['Author_Keywords'].str.contains(r'catalyst')|\
              df1['Keywords_Plus'].str.contains(r'catalyst')|\
              df1['Abstract'].str.contains(r'catalyst')]
    df4 = df4.reset_index(drop=True)
    #print(df4,'\n')
    print('catalyst:',len(df4))
    
    print(df4.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df5 = df1[df1['Article_Title'].str.contains(r'electrolyte') & df1['Article_Title'].str.contains(r'catalyst') & df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte') & df1['Author_Keywords'].str.contains(r'catalyst') & df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte') & df1['Keywords_Plus'].str.contains(r'catalyst') & df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte') & df1['Abstract'].str.contains(r'catalyst') & df1['Abstract'].str.contains(r'electrolyte')]
    df5 = df5.reset_index(drop=True)
    #print(df5,'\n')
    #print(len(df5))
    
    #print(df5.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df6 = df1[df1['Article_Title'].str.contains('transport')|\
              df1['Author_Keywords'].str.contains('transport')|\
              df1['Keywords_Plus'].str.contains('transport')|\
              df1['Abstract'].str.contains('transport')]
    df6 = df6.reset_index(drop=True)
    #print(df6,'\n')
    print('transport:',len(df6))
    
    print(df6.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    
    df7 = df1[df1['Article_Title'].str.contains('station|power generation')|\
              df1['Author_Keywords'].str.contains('station|power generation')|\
              df1['Keywords_Plus'].str.contains('station|power generation')|\
              df1['Abstract'].str.contains('station|power generation')]
    df7 = df7.reset_index(drop=True)
    #print(df7,'\n')
    print('station|power generation:',len(df7))
    
    #pd.options.display.max_colwidth = 500
    
    print(df7.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df8 = df1[df1['Article_Title'].str.contains('portable')|\
              df1['Author_Keywords'].str.contains('portable')|\
              df1['Keywords_Plus'].str.contains('portable')|\
              df1['Abstract'].str.contains('portable')]
    df8 = df8.reset_index(drop=True)
    #print(df8,'\n')
    print('portable:',len(df8))
    
    print(df8.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df9 = df1[df1['Article_Title'].str.contains('space')|\
              df1['Author_Keywords'].str.contains('space')|\
              df1['Keywords_Plus'].str.contains('space')|\
              df1['Abstract'].str.contains('space')]
    df9 = df9.reset_index(drop=True)
    #print(df9,'\n')
    print(len(df9))
    
    #print(df9.groupby(['Year']).size().reset_index(name='counts'),'\n')


keywords_stack4(data1)
# Out:
# 814
# 43
# electrode|anode|cathode: 25
#    Year  counts
# 0  2009       1
# 1  2011       1
# 2  2012       1
# 3  2014       2
# 4  2015       2
# 5  2016       7
# 6  2017       3
# 7  2018       3
# 8  2019       3
# 9  2020       2
#
# electrolyte: 16
#    Year  counts
# 0  2011       1
# 1  2012       2
# 2  2016       2
# 3  2017       4
# 4  2018       2
# 5  2019       5
#
# catalyst: 29
#    Year  counts
# 0  2009       1
# 1  2012       1
# 2  2014       1
# 3  2015       1
# 4  2016       7
# 5  2017       5
# 6  2018       4
# 7  2019       5
# 8  2020       4
#
# transport: 3
#    Year  counts
# 0  2016       1
# 1  2019       2
#
# station|power generation: 2
#    Year  counts
# 0  2019       2
#
# portable: 3
#    Year  counts
# 0  2019       2
# 1  2020       1
#
# 0

# %%
def keywords_stack5(x):
    a = x['Author Keywords'].str.lower()
    b = x['Publication Year']
    c = x['Article Title'].str.lower()
    d = x['Keywords Plus'].str.lower()
    e = x['Abstract'].str.lower()
    
    df = pd.DataFrame()
    df = df.assign(Year=b, Article_Title=c, Author_Keywords=a, Keywords_Plus=d, Abstract=e)
    df = df.reset_index(drop=True)
    print(len(df))
    
    df1 = df[df['Article_Title'].str.contains(r'photocatalytic|\bpfc\b')|\
             df['Author_Keywords'].str.contains(r'photocatalytic|\bpfc\b')|\
             df['Keywords_Plus'].str.contains(r'photocatalytic|\bpfc\b')|\
             df['Abstract'].str.contains(r'photocatalytic|\bpfc\b')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    print(len(df1))
    
    
    df2 = df1[df1['Article_Title'].str.contains(r'electrode|anode|cathode')|\
             df1['Author_Keywords'].str.contains(r'electrode|anode|cathode')|\
             df1['Keywords_Plus'].str.contains(r'electrode|anode|cathode')|\
             df1['Abstract'].str.contains(r'electrode|anode|cathode')]
    df2 = df2.reset_index(drop=True)
    #print(df2,'\n')
    print('electrode|anode|cathode:',len(df2))
    
    print(df2.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df3 = df1[df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte')]
    df3 = df3.reset_index(drop=True)
    #print(df3,'\n')
    print('electrolyte:',len(df3))
    
    print(df3.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df4 = df1[df1['Article_Title'].str.contains(r'catalyst')|\
              df1['Author_Keywords'].str.contains(r'catalyst')|\
              df1['Keywords_Plus'].str.contains(r'catalyst')|\
              df1['Abstract'].str.contains(r'catalyst')]
    df4 = df4.reset_index(drop=True)
    #print(df4,'\n')
    print('catalyst:',len(df4))
    
    print(df4.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df5 = df1[df1['Article_Title'].str.contains(r'electrolyte') & df1['Article_Title'].str.contains(r'catalyst') & df1['Article_Title'].str.contains(r'electrolyte')|\
              df1['Author_Keywords'].str.contains(r'electrolyte') & df1['Author_Keywords'].str.contains(r'catalyst') & df1['Author_Keywords'].str.contains(r'electrolyte')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte') & df1['Keywords_Plus'].str.contains(r'catalyst') & df1['Keywords_Plus'].str.contains(r'electrolyte')|\
              df1['Abstract'].str.contains(r'electrolyte') & df1['Abstract'].str.contains(r'catalyst') & df1['Abstract'].str.contains(r'electrolyte')]
    df5 = df5.reset_index(drop=True)
    #print(df5,'\n')
    #rint(len(df5))
    
    #print(df5.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df6 = df1[df1['Article_Title'].str.contains('transport')|\
              df1['Author_Keywords'].str.contains('transport')|\
              df1['Keywords_Plus'].str.contains('transport')|\
              df1['Abstract'].str.contains('transport')]
    df6 = df6.reset_index(drop=True)
    #print(df6,'\n')
    print('transport:',len(df6))
    
    print(df6.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    
    df7 = df1[df1['Article_Title'].str.contains('wastewater treatment')|\
              df1['Author_Keywords'].str.contains('wastewater treatment')|\
              df1['Keywords_Plus'].str.contains('wastewater treatment')|\
              df1['Abstract'].str.contains('wastewater treatment')]
    df7 = df7.reset_index(drop=True)
    #print(df7,'\n')
    print('wastewater treatment:',len(df7))
    
    #pd.options.display.max_colwidth = 500
    
    print(df7.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df8 = df1[df1['Article_Title'].str.contains('water splitting')|\
              df1['Author_Keywords'].str.contains('water splitting')|\
              df1['Keywords_Plus'].str.contains('water splitting')|\
              df1['Abstract'].str.contains('water splitting')]
    df8 = df8.reset_index(drop=True)
    #print(df8,'\n')
    print('water splitting:',len(df8))
    
    print(df8.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df9 = df1[df1['Article_Title'].str.contains('application')|\
              df1['Author_Keywords'].str.contains('application')|\
              df1['Keywords_Plus'].str.contains('application')|\
              df1['Abstract'].str.contains('application')]
    df9 = df9.reset_index(drop=True)
    #print(df9,'\n')
    #print(len(df9))
    
    #print(df9.groupby(['Year']).size().reset_index(name='counts'),'\n')

keywords_stack5(data1)
# Out:
# 814
# 36
# electrode|anode|cathode: 26
#    Year  counts
# 0  2014       1
# 1  2016       4
# 2  2017       4
# 3  2018       4
# 4  2019       5
# 5  2020       8
#
# electrolyte: 12
#    Year  counts
# 0  2016       2
# 1  2017       2
# 2  2018       2
# 3  2019       2
# 4  2020       4
#
# catalyst: 15
#    Year  counts
# 0  2014       1
# 1  2015       1
# 2  2016       1
# 3  2017       2
# 4  2018       2
# 5  2019       5
# 6  2020       3
#
# transport: 3
#    Year  counts
# 0  2014       1
# 1  2018       2
#
# wastewater treatment: 9
#    Year  counts
# 0  2016       2
# 1  2017       3
# 2  2018       1
# 3  2020       3
#
# water splitting: 4
#    Year  counts
# 0  2014       1
# 1  2016       1
# 2  2017       1
# 3  2020       1

# %%
def keywords_stack6(x):
    a = x['Author Keywords'].str.lower()
    b = x['Publication Year']
    c = x['Article Title'].str.lower()
    d = x['Keywords Plus'].str.lower()
    e = x['Abstract'].str.lower()
    
    df = pd.DataFrame()
    df = df.assign(Year=b, Article_Title=c, Author_Keywords=a, Keywords_Plus=d, Abstract=e)
    df = df.reset_index(drop=True)
    print(len(df))
    
    df1 = df[df['Article_Title'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b')|\
             df['Author_Keywords'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b')|\
             df['Keywords_Plus'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b')|\
             df['Abstract'].str.contains(r'polymer electrolyte|pefc|proton exchange|pemfc|\bpem\b')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    print(len(df1))
    
    
    df2 = df1[df1['Article_Title'].str.contains(r'electrode|anode|cathode')|\
             df1['Author_Keywords'].str.contains(r'electrode|anode|cathode')|\
             df1['Keywords_Plus'].str.contains(r'electrode|anode|cathode')|\
             df1['Abstract'].str.contains(r'electrode|anode|cathode')]
    df2 = df2.reset_index(drop=True)
    #print(df2,'\n')
    print('electrode|anode|cathode:',len(df2))
    
    print(df2.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df3 = df1[df1['Author_Keywords'].str.contains(r'electrolyte;|electrolytes;')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte;|electrolytes;')]
    df3 = df3.reset_index(drop=True)
    #print(df3,'\n')
    print('electrolyte:',len(df3))
    
    print(df3.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df4 = df1[df1['Article_Title'].str.contains(r'catalyst')|\
              df1['Author_Keywords'].str.contains(r'catalyst')|\
              df1['Keywords_Plus'].str.contains(r'catalyst')|\
              df1['Abstract'].str.contains(r'catalyst')]
    df4 = df4.reset_index(drop=True)
    #print(df4,'\n')
    print('catalyst:',len(df4))
    
    print(df4.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df5 = df1[df1['Article_Title'].str.contains(r'electrolyte') & df1['Article_Title'].str.contains(r'catalyst')|\
              df1['Author_Keywords'].str.contains(r'electrolyte') & df1['Author_Keywords'].str.contains(r'catalyst') & df1['Author_Keywords'].str.contains(r'electrolyte;|electrolytes;')|\
              df1['Keywords_Plus'].str.contains(r'electrolyte') & df1['Keywords_Plus'].str.contains(r'catalyst') & df1['Keywords_Plus'].str.contains(r'electrolyte;|electrolytes;')|\
              df1['Abstract'].str.contains(r'electrolyte') & df1['Abstract'].str.contains(r'catalyst')]
    df5 = df5.reset_index(drop=True)
    #print(df5,'\n')
    #print(len(df5))
    
    #print(df5.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df6 = df1[df1['Article_Title'].str.contains('transport')|\
              df1['Author_Keywords'].str.contains('transport')|\
              df1['Keywords_Plus'].str.contains('transport')|\
              df1['Abstract'].str.contains('transport')]
    df6 = df6.reset_index(drop=True)
    #print(df6,'\n')
    print('transport:',len(df6))
    
    print(df6.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    
    df7 = df1[df1['Article_Title'].str.contains('station|power generation')|\
              df1['Author_Keywords'].str.contains('station|power generation')|\
              df1['Keywords_Plus'].str.contains('station|power generation')|\
              df1['Abstract'].str.contains('station|power generation')]
    df7 = df7.reset_index(drop=True)
    #print(df7,'\n')
    print('station|power generation:',len(df7))
    
    #pd.options.display.max_colwidth = 500
    
    print(df7.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df8 = df1[df1['Article_Title'].str.contains('portable')|\
              df1['Author_Keywords'].str.contains('portable')|\
              df1['Keywords_Plus'].str.contains('portable')|\
              df1['Abstract'].str.contains('portable')]
    df8 = df8.reset_index(drop=True)
    #print(df8,'\n')
    print('portable:',len(df8))
    
    print(df8.groupby(['Year']).size().reset_index(name='counts'),'\n')
    
    df9 = df1[df1['Article_Title'].str.contains('application')|\
              df1['Author_Keywords'].str.contains('application')|\
              df1['Keywords_Plus'].str.contains('application')|\
              df1['Abstract'].str.contains('application')]
    df9 = df9.reset_index(drop=True)
    #print(df9,'\n')
    #print(len(df9))
    
    #print(df9.groupby(['Year']).size().reset_index(name='counts'),'\n')

keywords_stack6(data1)
# Out:
# 814
# 197
# electrode|anode|cathode: 53
#     Year  counts
# 0   2001       1
# 1   2003       1
# 2   2004       2
# 3   2006       1
# 4   2009       3
# 5   2010       2
# 6   2011       2
# 7   2012       3
# 8   2013       6
# 9   2014       1
# 10  2015       4
# 11  2016       5
# 12  2017       6
# 13  2018       4
# 14  2019       8
# 15  2020       4
#
# electrolyte: 31
#     Year  counts
# 0   2000       2
# 1   2002       1
# 2   2003       1
# 3   2006       3
# 4   2007       1
# 5   2008       1
# 6   2009       1
# 7   2010       2
# 8   2011       2
# 9   2012       4
# 10  2013       1
# 11  2014       1
# 12  2015       1
# 13  2016       2
# 14  2017       4
# 15  2018       1
# 16  2019       2
# 17  2020       1
#
# catalyst: 38
#     Year  counts
# 0   2001       1
# 1   2003       1
# 2   2004       3
# 3   2006       1
# 4   2009       1
# 5   2012       6
# 6   2013       5
# 7   2015       3
# 8   2016       3
# 9   2017       4
# 10  2018       2
# ...
