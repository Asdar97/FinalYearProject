# %%
import pandas as pd
from matplotlib import pyplot as pl
import math
import numpy as np
from collections import Counter
from pandas import ExcelWriter

# %%
data1 = pd.read_csv('Fuel cell (malaysia).csv')

# %%
data1
# Out:
#     Publication Type                                            Authors  \
# 0                  J  Abdullah, N; Saidur, R; Zainoodin, AM; Aslfatt...
# 1                  J  Al-Ogaili, AS; Ramasamy, A; Hashim, TJT; Al-Ma...
# 2                  J  Misha, S; Abdullah, AL; Tamaldin, N; Rosli, MA...
# 3                  J  Jalil, MH; Nasir, SNFM; Ismail, MI; Othman, MY...
# 4                  J  Basri, S; Hazri, NS; Selladurai, SR; Zainoodin...
# ..               ...                                                ...
# 809                J                     Nasef, MM; Saidi, H; Yarmo, MA
# 810                J            Nasef, MM; Saidi, H; Nor, HM; Yarmo, MA
# 811                J              Nasef, MM; Saidi, H; Nor, HM; Foo, OM
# 812                J         Lwin, Y; Daud, WRW; Mohamad, AB; Yaakob, Z
# 813                J                                          Nasef, MM
#
#      Book Authors  Book Editors  Book Group Authors  \
# ...

# %%
def collab(x):
    a = x['Addresses'].str.upper()
    b = x['Article Title'].str.lower()
    c = x['Publication Year']
    f = x['Times Cited, WoS Core']
    
    df = pd.DataFrame()
    df = df.assign(Organizations=a, Title=b, Publication_Year=c, Citations=f)
    df = df.reset_index(drop=True)
    #print(df)
    
    df1 = df[df['Organizations'].str.contains(r'UNIV KEBANGSAAN MALAYSIA|\bUKM\b|NATL UNIV MALAYSIA')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    
    df1 = df1[df1['Publication_Year'] == 2015]
    df1 = df1.reset_index(drop=True)
    df1 = df1.sort_values(by=['Citations'], ascending=False)
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    
    df1['Organizations'] = df1['Organizations'].str.replace(r"(\s*\[.*?\]\s*)", " ").str.strip()
    df1['Organizations'] = df1['Organizations'].apply(lambda x: x.split(';')[0])
    #print(df1,'\n')
    
    df2 = df1[df1['Organizations'].str.contains(r'UNIV KEBANGSAAN MALAYSIA|\bUKM\b|NATL UNIV MALAYSIA')]
    df2 = df2.reset_index(drop=True)
    print(df2,'\n')
    print('total 1st Authors from UKM:', len(df2))
    
    #df1.to_csv('Collab UKM - 2009.csv', index=False)
    
collab(data1)
# Out:
#                                         Organizations  \
# 0   UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, UKM ...
# 1   NATL UNIV MALAYSIA, FAC ENGN & BUILT ENVIRONM,...
# 2   UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, BANG...
# 3   UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, UKM ...
# 4   UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, BANG...
# 5   UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, UKM ...
# 6   UNIV KEBANGSAAN MALAYSIA, FAC ENGN & BUILT ENV...
# 7   UNIV KEBANGSAAN MALAYSIA, FAC ENGN & BUILT ENV...
# 8   UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, UKM ...
# 9   UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, BANG...
# 10  UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, UKM ...
# 11  UNIV KEBANGSAAN MALAYSIA, FUEL CELL INST, UKM ...
#
#                                                 Title  Publication_Year  \
# 0   composite membrane containing graphene oxide i...              2015
# 1   hydrogen gas production with an electroformed ...              2015
# ...

# %%
def collab(x):
    a = x['Addresses'].str.upper()
    b = x['Article Title'].str.lower()
    c = x['Publication Year']
    f = x['Times Cited, WoS Core']
    
    df = pd.DataFrame()
    df = df.assign(Organizations=a, Title=b, Publication_Year=c, Citations=f)
    df = df.reset_index(drop=True)
    #print(df)
    
    df1 = df[df['Organizations'].str.contains(r'UNIV TEKNOL MALAYSIA|UNIV TECHNOL MALAYSIA|UNIV TEKNOLOGI MALAYSIA|\bUTM\b')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    
    df1 = df1[df1['Publication_Year'] == 2020]
    df1 = df1.reset_index(drop=True)
    df1 = df1.sort_values(by=['Citations'], ascending=False)
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    
    df1['Organizations'] = df1['Organizations'].str.replace(r"(\s*\[.*?\]\s*)", " ").str.strip()
    df1['Organizations'] = df1['Organizations'].apply(lambda x: x.split(';')[0])
    #print(df1,'\n')
    
    df2 = df1[df1['Organizations'].str.contains(r'UNIV TEKNOL MALAYSIA|UNIV TECHNOL MALAYSIA|UNIV TEKNOLOGI MALAYSIA|\bUTM\b')]
    df2 = df2.reset_index(drop=True)
    print(df2,'\n')
    print('total 1st Authors from UTM:', len(df2))
    
    #df1.to_csv('Collab UKM - 2009.csv', index=False)
    
collab(data1)
# Out:
#                                        Organizations  \
# 0  UNIV TEKNOL MALAYSIA, FAC ENGN, ADV MEMBRANE T...
# 1  UNIV TEKNOL MALAYSIA, FAC ENGN, SCH CHEM & ENE...
# 2  UNIV TEKNOL MALAYSIA, FAC ENGN, SCH CHEM & ENE...
# 3  UNIV TEKNOL MALAYSIA, FAC SCI, DEPT CHEM, JOHO...
# 4  UNIV TEKNOL MALAYSIA, ADV MEMBRANE TECHNOL RES...
# 5  UNIV TEKNOL MALAYSIA, FAC CHEM & ENERGY ENGN F...
# 6  UNIV TEKNOL MALAYSIA, SCH ELECT ENGN, JOHOR BA...
# 7  UNIV TEKNOL MALAYSIA UTM, FAC SCI, DEPT PHYS, ...
# 8  UNIV TEKNOL MALAYSIA, FAC CHEM & ENERGY ENGN, ...
#
#                                                Title  Publication_Year  \
# 0  development of high-performance anode/electrol...              2020
# 1  an advanced, efficient and highly durable of r...              2020
# 2  high degree sulfonated poly(ether ether ketone...              2020
# 3  mild sulfonated polyether ketone ether ketone ...              2020
# 4  effect of electrolyte thickness manipulation o...              2020
# ...

# %%
def collab(x):
    a = x['Addresses'].str.upper()
    b = x['Article Title'].str.lower()
    c = x['Publication Year']
    f = x['Times Cited, WoS Core']
    
    df = pd.DataFrame()
    df = df.assign(Organizations=a, Title=b, Publication_Year=c, Citations=f)
    df = df.reset_index(drop=True)
    #print(df)
    
    df1 = df[df['Organizations'].str.contains(r'UNIV MALAYA|UNIV MALAYSIA, KUALA LUMPUR|\bUM\b')]
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    
    df1 = df1[df1['Publication_Year'] == 2020]
    df1 = df1.reset_index(drop=True)
    df1 = df1.sort_values(by=['Citations'], ascending=False)
    df1 = df1.reset_index(drop=True)
    #print(df1,'\n')
    
    df1['Organizations'] = df1['Organizations'].str.replace(r"(\s*\[.*?\]\s*)", " ").str.strip()
    df1['Organizations'] = df1['Organizations'].apply(lambda x: x.split(';')[0])
    #print(df1,'\n')
    
    df2 = df1[df1['Organizations'].str.contains(r'UNIV MALAYA|UNIV MALAYSIA, KUALA LUMPUR|\bUM\b')]
    df2 = df2.reset_index(drop=True)
    print(df2,'\n')
    print('total 1st Authors from UM:', len(df2))
    
    #df1.to_csv('Collab UKM - 2009.csv', index=False)
    
collab(data1)
# Out:
#                                        Organizations  \
# 0  UNIV MALAYA, NANOTECHNOL & CATALYSIS RES CTR, ...
# 1  UNIV MALAYA, INST ADV STUDIES, KUALA LUMPUR 50...
# 2  UNIV MALAYA, INST ADV STUDIES BLDG, INST OCEAN...
# 3  UNIV MALAYA, FAC SCI, PHYS DEPT, KUALA LUMPUR ...
#
#                                                Title  Publication_Year  \
# 0  reduced graphene/nanostructured cobalt oxide n...              2020
# 1  vital parameters for biomass, lipid, and carot...              2020
# 2  algal biophotovoltaic devices: surface potenti...              2020
# 3  optimal heat recovery using photovoltaic therm...              2020
#
#    Citations
# 0          5
# 1          2
# 2          1
# 3          0
#
# total 1st Authors from UM: 4
